# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
from sklearn import preprocessing
from scipy.io.wavfile import read
from sklearn.mixture import GaussianMixture
import python_speech_features as mfcc
# %matplotlib inline

# %%
path = "./dataset/Vaidehi/"

# %%
os.listdir(path)[0].split("_")
# Out:
# ['Awaaz.wav']

# %%
for file in os.listdir(path):
    filename = path + file
    print(filename)
    os.rename(filename, f'''{path}2193274_{file.split("_")[-1]}''')
# Out:
# ./dataset/Vaidehi/Awaaz.wav
# ./dataset/Vaidehi/Bonjour.wav
# ./dataset/Vaidehi/Brown%20fox.wav
# ./dataset/Vaidehi/Dataset.wav
# ./dataset/Vaidehi/Hello%20world.wav
# ./dataset/Vaidehi/Konichiwa.wav
# ./dataset/Vaidehi/Kya%20ho%20rha.wav
# ./dataset/Vaidehi/One%20two.wav
# ./dataset/Vaidehi/Python.wav

# %%
import numpy as np
import matplotlib.pyplot as plt
import base64

# %%
import base64

# %%
base64_string = "..."

# %%
audio_data = base64.urlsafe_b64decode(base64_string)

audio = open("./converted_audio8.wav", "wb")
audio.write(audio_data)
# Out:
# 12778

# %%
buffer = "data:audio/wav; codecs=ms_pcm;base64,..."

# %%
buffer = buffer.split(",")[1]
buffer
# Out:
# '...'

# %%
audio_data = base64.urlsafe_b64decode(buffer)

audio = open("./converted_audio9.wav", "wb")
audio.write(audio_data)
# Out:
# 13111
